# %%
# Dependencies and Setup
import csv
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from api_key import cde_api_key

print(cde_api_key)
# Out:
# KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn

# %%
file_path = "./state_id.csv"
state_id_df = pd.read_csv(file_path)
print(state_id_df)
# Out:
#    State_ID                           State
# 0        AL                         Alabama
# 1        AK                          Alaska
# 2        AS                  American Samoa
# 3        AZ                         Arizona
# 4        AR                        Arkansas
# 5        CA                      California
# 6        CO                        Colorado
# 7        CT                     Connecticut
# 8        DE                        Delaware
# 9        DC            District Of Columbia
# 10       FM  Federated States Of Micronesia
# 11       FL                         Florida
# 12       GA                         Georgia
# 13       GU                            Guam
# 14       HI                          Hawaii
# 15       ID                           Idaho
# 16       IL                        Illinois
# 17       IN                         Indiana
# 18       IA                            Iowa
# 19       KS                          Kansas
# 20       KY                        Kentucky
# 21       LA                       Louisiana
# 22       ME                           Maine
# 23       MH                Marshall Islands
# 24       MD                        Maryland
# 25       MA                   Massachusetts
# 26       MI                        Michigan
# 27       MN                       Minnesota
# 28       MS                     Mississippi
# 29       MO                        Missouri
# 30       MT                         Montana
# 31       NE                        Nebraska
# 32       NV                          Nevada
# 33       NH                   New Hampshire
# 34       NJ                      New Jersey
# 35       NM                      New Mexico
# 36       NY                        New York
# 37       NC                  North Carolina
# 38       ND                    North Dakota
# 39       MP        Northern Mariana Islands
# 40       OH                            Ohio
# 41       OK                        Oklahoma
# 42       OR                          Oregon
# 43       PW                           Palau
# 44       PA                    Pennsylvania
# 45       PR                     Puerto Rico
# 46       RI                    Rhode Island
# 47       SC                  South Carolina
# 48       SD                    South Dakota
# 49       TN                       Tennessee
# 50       TX                           Texas
# 51       UT                            Utah
# 52       VT                         Vermont
# 53       VI                  Virgin Islands
# 54       VA                        Virginia
# 55       WA                      Washington
# 56       WV                   West Virginia
# 57       WI                       Wisconsin
# 58       WY                         Wyoming

# %%
pd.DataFrame(state_id_df)
# Out:
#    State_ID                           State
# 0        AL                         Alabama
# 1        AK                          Alaska
# 2        AS                  American Samoa
# 3        AZ                         Arizona
# 4        AR                        Arkansas
# 5        CA                      California
# 6        CO                        Colorado
# 7        CT                     Connecticut
# 8        DE                        Delaware
# 9        DC            District Of Columbia
# 10       FM  Federated States Of Micronesia
# 11       FL                         Florida
# 12       GA                         Georgia
# 13       GU                            Guam
# 14       HI                          Hawaii
# 15       ID                           Idaho
# 16       IL                        Illinois
# 17       IN                         Indiana
# 18       IA                            Iowa
# 19       KS                          Kansas
# 20       KY                        Kentucky
# 21       LA                       Louisiana
# 22       ME                           Maine
# 23       MH                Marshall Islands
# 24       MD                        Maryland
# 25       MA                   Massachusetts
# 26       MI                        Michigan
# 27       MN                       Minnesota
# 28       MS                     Mississippi
# 29       MO                        Missouri
# 30       MT                         Montana
# 31       NE                        Nebraska
# 32       NV                          Nevada
# 33       NH                   New Hampshire
# 34       NJ                      New Jersey
# 35       NM                      New Mexico
# 36       NY                        New York
# 37       NC                  North Carolina
# 38       ND                    North Dakota
# 39       MP        Northern Mariana Islands
# 40       OH                            Ohio
# 41       OK                        Oklahoma
# 42       OR                          Oregon
# 43       PW                           Palau
# 44       PA                    Pennsylvania
# 45       PR                     Puerto Rico
# 46       RI                    Rhode Island
# 47       SC                  South Carolina
# 48       SD                    South Dakota
# 49       TN                       Tennessee
# 50       TX                           Texas
# 51       UT                            Utah
# 52       VT                         Vermont
# 53       VI                  Virgin Islands
# 54       VA                        Virginia
# 55       WA                      Washington
# 56       WV                   West Virginia
# 57       WI                       Wisconsin
# 58       WY                         Wyoming

# %%
state_id_df.loc[:, ["State_ID"]].head()
# Out:
#   State_ID
# 0       AL
# 1       AK
# 2       AS
# 3       AZ
# 4       AR

# %%
state_id_list = state_id_df["State_ID"].tolist()
print(state_id_list)
# Out:
# ['AL', 'AK', 'AS', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FM', 'FL', 'GA', 'GU', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MH', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'MP', 'OH', 'OK', 'OR', 'PW', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VI', 'VA', 'WA', 'WV', 'WI', 'WY']

# %%
for state_id in state_id_list:
    print(state_id)
# Out:
# AL
# AK
# AS
# AZ
# AR
# CA
# CO
# CT
# DE
# DC
# FM
# FL
# GA
# GU
# HI
# ID
# IL
# IN
# IA
# KS
# KY
# LA
# ME
# MH
# MD
# MA
# MI
# MN
# MS
# MO
# MT
# NE
# NV
# NH
# NJ
# NM
# NY
# NC
# ND
# MP
# OH
# OK
# OR
# PW
# PA
# PR
# RI
# SC
# SD
# TN
# TX
# UT
# VT
# VI
# VA
# WA
# WV
# WI
# WY

# %%
for state_id in state_id_list:
    url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{state_id}/property_crime?from=2017&to=2021&API_KEY={cde_api_key}"
    print(url)
# Out:
# https://api.usa.gov/crime/fbi/cde/arrest/state/AL/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/AK/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/AS/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/AZ/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/AR/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/CA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/CO/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/CT/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/DE/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/DC/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/FM/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/FL/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/GA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/GU/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/HI/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/ID/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/IL/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/IN/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/IA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/KS/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/KY/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/LA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/ME/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MH/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MD/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MI/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MN/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MS/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MO/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MT/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NE/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NV/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NH/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NJ/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NM/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NY/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/NC/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/ND/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/MP/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/OH/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/OK/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/OR/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/PW/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/PA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/PR/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/RI/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/SC/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/SD/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/TN/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/TX/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/UT/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/VT/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/VI/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/VA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/WA/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/WV/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/WI/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn
# https://api.usa.gov/crime/fbi/cde/arrest/state/WY/property_crime?from=2017&to=2021&API_KEY=KX3EgNxVLiRyc2XiWtYS7BF6UsBtmF25aszpVsn

# %%
data_list = []

for state_id in state_id_list:
    url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{state_id}/property_crime?from=2017&to=2021&API_KEY={cde_api_key}"
    response = requests.get(url).json()

    data = response["data"]
    if "data" in json_response:
            data = json_response["data"]
            ...
    else:
            print(f"No 'data' key in response for state_id: {state_id}")
            print(json_response)

    
    for data_list_response in data:
        data_list_response ["state"] = state_id
        data_list.append(data_list_response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 7
#       4 url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{state_id}/property_crime?from=2017&to=2021&API_KEY={cde_api_key}"
#       5 response = requests.get(url).json()
# ----> 7 data = response["data"]
#       8 if "data" in json_response:
#       9         data = json_response["data"]
#
# KeyError: 'data'

# %%
data_list = []

for state_id in state_id_list:
    url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{state_id}/property_crime?from=2017&to=2021&API_KEY={cde_api_key}"
    response = requests.get(url).json()

    data = response["data"]
    for data_list_response in data:
        data_list_response ["state"] = state_id
        data_list.append(data_list_response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 7
#       4 url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{state_id}/property_crime?from=2017&to=2021&API_KEY={cde_api_key}"
#       5 response = requests.get(url).json()
# ----> 7 data = response["data"]
#       8 for data_list_response in data:
#       9     data_list_response ["state"] = state_id
#
# KeyError: 'data'

# %%
data_list
# Out:
# []
